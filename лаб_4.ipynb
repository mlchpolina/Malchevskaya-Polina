# %% [markdown]
# № 4.2.1
#
# Рассчитать значение f при заданном значении вещественного числа x:
#
# f(x)=⎧⎩⎨⎪⎪x−−√+x2,1x,при x⩾0,в противном случае.
# При выводе на экран оставьте 2 знака после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_01.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201


import math
x =  float(input("введите значение X  "))

if x >= 0:
    f=math.sqrt(x)+x**2
else:
    f = 1 / x

print(round(f,2))

# --------------
# Пример вывода:
#
# Введите число x: -10
# f = -0.10

# Введите число x: 0
# f = 0.00

# Введите число x: 10
# f = 103.16
# Out:
# введите значение X  10
# 103.16

# %% [markdown]
# № 4.2.2
#
# Определите максимальное и минимальное значения из двух различных целых чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_02.
#
# Выполнил: Мальчевская П.А.
# Группа: АЛЭУ-201
# E-mail: !!!


a1 = int(input("введите а1  "))
a2=  int(input("введите a2  "))

if a1>a2:
  print("максимум", a1)
else:
  print("максимум", a2)

if a1<a2:
  print("минимум", a1)
else:
  print("минимум", a2)

if a1==a2:
  print("числа равны")
# --------------
# Пример вывода:
#
# Введите первое число: 1
# Введите второе число: 2
# Максимум: 2, минимум: 1

# Введите первое число: 5
# Введите второе число: 5
# Максимум: 5, минимум: 5

# Введите первое число: 100
# Введите второе число: -1
# Максимум: 100, минимум: -1
# Out:
# введите а1  5
# введите a2  5
# максимум 5
# минимум 5
# числа равны

# %% [markdown]
# № 4.2.3
#
# Вася пытается высунуть голову в форточку размерами a и b см. Приняв условно, что его голова - круглая диаметром d см, определите, сможет ли Вася сделать это. Для прохождения головы в форточку необходим зазор в 1 см. с каждой стороны.
#
# Все величины - целые числа.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_03.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


a = int(input("введите ширину форточки "))
b = int(input("введите высоту форточки "))
d = int(input("введите диаметр головы "))


if a>0 and b>0:
    fix = 1  # Зазор
    if a>= d+2*fix and b>= d+2*fix:
      print("да")
    else:
      print("нет")
else:
    print("проверьте ввод")
# --------------
# Пример вывода:
#
# Ширина форточки: 5
# Высота форточки: 6
# Диаметр головы: 6
# Нет

# Ширина форточки: 6
# Высота форточки: 7
# Диаметр головы: 4
# Да
# Out:
# введите ширину форточки 6
# введите высоту форточки 7
# введите диаметр головы 4
# да

# %% [markdown]
# № 4.2.4
#
# Известны год и номер месяца сегодняшнего дня, а также год и номер месяца рождения человека (нумерация месяцев с 1: январь - 1 и т.д.). Определите возраст человека (число полных лет).

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_04.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


year_today = int(input("введите текущий год "))
month_today = int(input("введите текущий месяц "))

year = int(input("введите год рождения "))
month = int(input("введите месяц рождения "))

age = year_today - year
age_month = month_today - month

if age_month < 1:
  age = age - 1
  age_month = age_month + 12

print("Число полных лет:", age)

# --------------
# Пример вывода:
#
# Введите текущий год: 2017
# Введите текущий месяц: 5
# Введите год рождения: 2000
# Введите месяц рождения: 1
# Число полных лет:  17
#
# Введите текущий год: 2015
# Введите текущий месяц: 6
# Введите год рождения: 2010
# Введите месяц рождения: 8
# Число полных лет:  4
#
# Введите текущий год: 2020
# Введите текущий месяц: 5
# Введите год рождения: 2000
# Введите месяц рождения: 5
# Число полных лет:  20
# Out:
# введите текущий год 2015
# введите текущий месяц 6
# введите год рождения 2010
# введите месяц рождения 8
# Число полных лет: 4

# %% [markdown]
# № 4.2.5
#
# Дана точка с целыми ненулевыми координатами (x;y). Определить номер четверти координатной плоскости, которой она принадлежит.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_05.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


x = int(input("x="))
y = int(input("y="))

if x > 0 and y > 0:
    print("1-я четверть")

elif x < 0 and y > 0:
    print("2 четверть")

elif x < 0 and y < 0:
    print("3 четверть")

else:
    print("4 четверть")

# --------------
# Пример вывода:
#
# Введите координату x: 5
# Введите координату y: 7
# 1-я четверть
# Out:
# x=5
# y=7
# 1-я четверть

# %% [markdown]
# № 4.2.6
#
# Даны вещественные числа a, b, c (a≠0).
#
# Решите уравнение ax2+bx+c=0. При выводе значений оставьте 1 знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_06.
#
# Выполнил: Мальчевская П.А.
# Группа: !!!
# E-mail: !!!


a = # Удалите комментарий и допишите код
b = # Удалите комментарий и допишите код
c = # Удалите комментарий и допишите код

# Расчет дискриминанта
# Удалите комментарий и допишите код

# Вывод решения в зависимости от значения дискриминанта
# При выводе значений оставьте 1 знак после запятой
# Удалите комментарий и допишите код

# --------------
# Пример вывода:
#
# a = 1
# b = 2
# c = 3
# Решений нет
#
# a = 1
# b = 2
# c = 1
# x = -1.0
#
# a = 1
# b = 3
# c = -4
# x1 = -4.0, x2 = 1.0

# %% [markdown]
# № 4.2.7
#
# Дана непустая последовательность целых чисел, оканчивающаяся нулем. Найти сумму и количество введенных чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_07.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


nums_sum = 0  # сумма
nums_count = 0  # количество

x = int(input("введите число  "))
while x != 0:
    nums_sum= nums_sum+x
    nums_count=nums_count+1
    x=int(input("введите число ")) #новое число последовательности 

print("сумма", nums_sum)
print("количество", nums_count)

# --------------
# Пример вывода:
#
# Введите 1-е число: 1
# Введите 2-е число: 2
# Введите 3-е число: 3
# Введите 4-е число: 4
# Введите 5-е число: 0
# Сумма = 10
# Количество = 4
#
# Введите 1-е число: 0
# Сумма = 0
# Количество = 0
# Out:
# введите число  1
# введите число 2
# введите число 3
# введите число 4
# введите число 0
# сумма 10
# количество 4

# %% [markdown]
# № 4.2.8
#
# Дано число n. Из чисел 0,5,10,15,20,25,... напечатать те, которые не превышают n.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_08.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


n = int(input("введите n "))
i=0

while (n/5)>=0:
  print(i)
  i=i+5
  n=n-5



# --------------
# Пример вывода:
#
# n = 0
# 0
#
# n = 10
# 0
# 5
# 10
#
# n = 12
# 0
# 5
# 10
# Out:
# введите n 12
# 0
# 5
# 10

# %% [markdown]
# № 4.2.9
#
# Дано вещественное число a. Найдите наименьшее натуральное n, для которого верно
#
# 1+12+13+...+1n>a

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_09.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!

a = float(input("a="))

n=0
x_sum = 0


while x_sum <= a:
  n = n + 1
  x_sum = x_sum + 1/n

print("n=",n)

# --------------
# Пример вывода:
#
# a = 1.5
# n = 3
#
# a = 2
# n = 4
# Out:
# a=2
# n= 4

# %% [markdown]
# № 4.2.10
#
# Дано натуральное число. Определите сумму и количество его цифр.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_10.
#
# Выполнил: Мальчевская П.А.
# E-mail: !!!



n = int(input("n="))

n_sum = 0
n_count = 0

while n > 0:
  m=n%10
  n_sum = n_sum + m
  n_count = n_count + 1
  n = n // 10                               #шаг

print("cумма =", n_sum)
print("количество =", n_count)

# --------------
# Пример вывода:
#
# n = 12345
# Сумма = 15
# Количество = 5
# Out:
# n=963
# cумма = 18
# количество = 3

# %% [markdown]
# № 4.2.11
#
# Вывести в строку 10 первых натуральных чисел, оканчивающихся на цифру k, кратных числу s и находящихся в интервале, левая граница которого равна start.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_11.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!

start = int(input("start="))
k = int(input("k="))
s = int(input("s="))
n_count = 0

while n_count != 10:
  if (start % 10 == k) and (start % s == 0):
    print(start, end= ' ')
    n_count = n_count + 1
  start = start + 1
# --------------
# Пример вывода:
#
# start = 100
# k = 7
# s = 9
# 117 207 297 387 477 567 657 747 837 927
# Out:
# start=20
# k=5
# s=3
# 45 75 105 135 165 195 225 255 285 315

# %% [markdown]
# № 4.2.12
#
# Даны целые числа a и b (a может быть больше b). Напечатайте:
#
# числа от минимального до максимального в строчку (разделяя пробелом);
#
# числа от максимального до минимального «столбиком».

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_12.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


a = int(input("a="))
b = int(input("b="))

if a > b:
  min = b
  max = a
else:
  min = a
  max = b

#от мин до макс в строчку
while min <= max:
  print(min, end= ' ')
  min = min + 1

print("\n")

if a > b:
  min = b
  max = a
else:
  min = a
  max = b

#от макс до мин в столб
while max >= min:
  print(max, end= "\n")
  max = max - 1
# --------------
# Пример вывода:
#
# a = 1
# b = 5
# 1 2 3 4 5
# 5
# 4
# 3
# 2
# 1
# Out:
# a=4
# b=9
# 4 5 6 7 8 9
#
# 9
# 8
# 7
# 6
# 5
# 4

# %% [markdown]
# № 4.2.13
#
# Для введенных с клавиатуры положительных целых чисел a и b (a≤b) определите:
#
# сумму всех целых чисел от a до b;
#
# произведение всех целых чисел от a до b;
#
# среднее арифметическое всех целых чисел от a до b;
#
# среднее геометрическое нечетных чисел от a до b.
#
# Отрезок поиска включает сами числа a и b. При выводе вещественных результатов оставьте два знака после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_13.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!

import math

a = int(input("a="))
b = int(input("b="))

if a <= 0 and b <= 0:
  print("попробуйте снова")
  
n_sum = 0
n_mult = 1   #для всех
count = 0
mult = 1     #для нечетных

while a <= b:
  count = count + 1
  n_sum = n_sum + a
  n_mult = n_mult * a
  if a % 2 != 0:
    mult = mult * a
  a = a + 1


n_avg = n_sum / count
n_avg_geom = math.sqrt(mult)


print("сумма =", n_sum)
print("произведение =", n_mult)
print("среднее арифметическое =", round(n_avg, 2))
print("среднее геометрическое нечетных чисел =", round(n_avg_geom, 2))

# --------------
# Пример вывода:
#
# a = 1
# b = 5
# Сумма = 15
# Произведение = 120
# Среднее арифметическое = 3.00
# Среднее геометрическое нечетных чисел = 2.47
# Out:
# a=1
# b=5
# сумма = 15
# произведение = 120
# среднее арифметическое = 3.0
# среднее геометрическое нечетных чисел = 3.87

# %% [markdown]
# № 4.2.14
#
# Начав тренировки, лыжник в первый день пробежал s км. (s>0, вещественное число). Каждый следующий день он увеличивал пробег на p % (0<p≤100, вещественное число) от пробега предыдущего дня. Определите:
#
# пробег лыжника за второй, третий, …, десятый день тренировок;
#
# какой суммарный путь он пробежал за первые 10 дней тренировок.
#
# При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_14.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


s = float(input("пробежал за 1 день: "))
p = float(input("увеличил на процентов"))

total = s

for i in range(2, 11, 1):
  s = s + s * (p / 100)
  total = total + s
  print("пробежал за ", i, "- й день: ", round(s, 3), "км")


print("суммарный пробег: ", round(total, 1))

# --------------
# Пример вывода:
#
# Пробег за 1-й день (км.) = 5
# На сколько увеличивает пробег (%) = 10
# Пробег за 2-й день: 5.5 км.
# Пробег за 3-й день: 6.1 км.
# Пробег за 4-й день: 6.7 км.
# Пробег за 5-й день: 7.3 км.
# Пробег за 6-й день: 8.1 км.
# Пробег за 7-й день: 8.9 км.
# Пробег за 8-й день: 9.7 км.
# Пробег за 9-й день: 10.7 км.
# Пробег за 10-й день: 11.8 км.
# Суммарный пробег: 79.7 км.
# Out:
# пробежал за 1 день: 5
# увеличил на процентов10
# пробежал за  2 - й день:  5.5 км
# пробежал за  3 - й день:  6.05 км
# пробежал за  4 - й день:  6.655 км
# пробежал за  5 - й день:  7.32 км
# пробежал за  6 - й день:  8.053 км
# пробежал за  7 - й день:  8.858 км
# пробежал за  8 - й день:  9.744 км
# пробежал за  9 - й день:  10.718 км
# пробежал за  10 - й день:  11.79 км
# суммарный пробег:  79.7

# %% [markdown]
# № 4.2.15
#
# Известна масса каждого предмета в кг., загружаемого в грузовик. Определить, возможна ли перевозка груза, если грузоподъемность грузовика равна p кг.

# %%
#Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_15.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


p = int(input("грузоподъемность ")) 
n = int(input("количество перевозимых предметов ")) 

total = 0 # суммарный вес всех предметов

for i in range (1, n+1, 1):
  m = float(input("введите массу : "))
  total += m

if total < p:
  print("перевозка возможна")
else:
  print("перевозка невозможна")

# --------------
# Пример вывода:
#
# Грузоподъемность грузовика (кг.) = 10
# Количество предметов = 2
# Масса 1-го предмета (кг.) = 3
# Масса 2-го предмета (кг.) = 3
# Да
# Out:
# грузоподъемность 3
# количество перевозимых предметов 3
# введите массу : 0.5
# введите массу : 0.4
# введите массу : 2
# перевозка возможна

# %% [markdown]
# № 4.2.16
#
# В области несколько районов. Заданы площади, засеваемые пшеницей (га.), и средняя урожайность (ц/га) в каждом районе.
#
# Определите количество пшеницы, собранное по области. При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_16.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!


n = int(input("введите кол-во районов "))

total = 0

for i in range(1, n + 1, 1):
  s = float(input("введите площадь района "))
  sr = float(input("введите значение средней урожайности "))
  total = total + s * sr*n

print(round(total,2))
# Out:
# введите кол-во районов 2
# введите площадь района 40.3
# введите значение средней урожайности 5
# введите площадь района 20.1
# введите значение средней урожайности 3
# 523.6

# %% [markdown]
# № 4.2.19
#
# Выведите на экран (в строку) все целые числа от a до b, кратные некоторому числу c.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_19.
#
# Выполнил: Мальчевская П.А.
# Группа: АДЭУ-201
# E-mail: !!!

a = int(input("a="))
b = int(input("b="))
c = int(input("c="))

count = 0

for i in range(a, b + 1, 1):
  if (a % c == 0) and (b % c == 0):
    print(a, end= ' ')
    count = count + 1
  a = a + 1

# --------------
# Пример вывода:
#
# a = 1
# b = 10
# c = 2
# 2 4 6 8 10
# Out:
# a=1
# b=20
# c=5
# 5 10 15 20
